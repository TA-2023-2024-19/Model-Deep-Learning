# %% [markdown]
# # **Setup**

# %%
# Cek Akses GPU
# !nvidia-smi
# Out:
# Tue Jun 18 02:44:26 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   43C    P8              12W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# Menampilkan path saat ini
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Install YOLOv8

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Setup complete ✅ (12 CPUs, 53.0 GB RAM, 30.2/78.2 GB disk)

# %%
# Library untuk display image
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# # **Splitting Dataset**

# %% [markdown]
# ## **Splitting Dataset 60:40_10**

# %%
# Dataset 60:40_10

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="S4lowXmzTCfZjsbHzuzA")
project = rf.workspace("herbalplant").project("herbal-plant-w0fkh")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# Train Dataset 60:40_10

# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=25 imgsz=640 plots=True
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 384MB/s]
# New https://pypi.org/project/ultralytics/8.2.32 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ## **Splitting Dataset 70:30_10**

# %%
# Import Dataset 70:30_10

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="S4lowXmzTCfZjsbHzuzA")
project = rf.workspace("herbalplant").project("herbal-plant-w0fkh")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Herbal-Plant-2 in yolov8:: 100%|██████████| 4902/4902 [00:00<00:00, 6013.69it/s]

# %%
# Train Dataset 70:30_10

# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data=/content/Herbal-Plant-2/data.yaml epochs=25 imgsz=640 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.2.32 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ## **Splitting Dataset 80:20_10**

# %%
# Import Dataset 80:20_10

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="S4lowXmzTCfZjsbHzuzA")
project = rf.workspace("herbalplant").project("herbal-plant-w0fkh")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Herbal-Plant-3 in yolov8:: 100%|██████████| 5394/5394 [00:00<00:00, 5814.47it/s]

# %%
# Train Dataset 80:20_10

# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data=/content/Herbal-Plant-3/data.yaml epochs=25 imgsz=640 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.2.32 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ## **Splitting Dataset 90:10_10**

# %%
# Import Dataset 80:20_10

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="S4lowXmzTCfZjsbHzuzA")
project = rf.workspace("herbalplant").project("herbal-plant-w0fkh")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Herbal-Plant-4 in yolov8:: 100%|██████████| 5892/5892 [00:00<00:00, 5951.43it/s]

# %%
# Train Dataset 90:10_10

# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data=/content/Herbal-Plant-4/data.yaml epochs=25 imgsz=640 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.2.32 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
from ultralytics import YOLO

# Load the last model
model = YOLO('/content/runs/detect/train4/weights/last.pt')
# Validate the model
results = model.val()

# Print the results
print(results)
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/Herbal-Plant-4/valid/labels.cache... 62 images, 0 backgrounds, 0 corrupt: 100%|██████████| 62/62 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/4 [00:00<?, ?it/s]Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:03<00:00,  1.21it/s]
#                    all         62         75      0.934      0.967       0.98      0.796
#            Daun Kunyit         62         51       0.84      0.902      0.949      0.734
# ...

# %% [markdown]
# ## **Splitting Dataset 90:10_10 NEW**

# %%
# Import Dataset 90:10_10  -> NEW 81:9:10

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="S4lowXmzTCfZjsbHzuzA")
project = rf.workspace("herbalplant").project("herbal-plant-w0fkh")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Herbal-Plant-5 in yolov8:: 100%|██████████| 5888/5888 [00:00<00:00, 5942.95it/s]

# %%
# Train Dataset 90:10_10 -> NEW

# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data=/content/Herbal-Plant-5/data.yaml epochs=25 imgsz=640 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.2.32 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ## **Splitting Dataset 80:20_10 NEW**

# %%
# NEW 80:20_10 - 72:18:10


# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="S4lowXmzTCfZjsbHzuzA")
project = rf.workspace("herbalplant").project("herbal-plant-w0fkh")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Herbal-Plant-6 in yolov8:: 100%|██████████| 5388/5388 [00:00<00:00, 5906.78it/s]

# %%
# Train Dataset 80:20_10 -> NEW

# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data=/content/Herbal-Plant-6/data.yaml epochs=25 imgsz=640 plots=True
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# Ubah 'folder_name' ke nama folder yang ingin Anda zip
folder_name = '/content/runs/detect/train9'

# Jalankan perintah zip di shell
# !zip -r {folder_name}.zip {folder_name}
# Out:
#   adding: content/runs/detect/train9/ (stored 0%)
#   adding: content/runs/detect/train9/train_batch2.jpg (deflated 1%)
#   adding: content/runs/detect/train9/val_batch1_pred.jpg (deflated 5%)
#   adding: content/runs/detect/train9/val_batch1_labels.jpg (deflated 5%)
#   adding: content/runs/detect/train9/R_curve.png (deflated 10%)
#   adding: content/runs/detect/train9/results.png (deflated 6%)
#   adding: content/runs/detect/train9/P_curve.png (deflated 10%)
#   adding: content/runs/detect/train9/train_batch2340.jpg (deflated 4%)
#   adding: content/runs/detect/train9/train_batch2341.jpg (deflated 6%)
#   adding: content/runs/detect/train9/PR_curve.png (deflated 17%)
#   adding: content/runs/detect/train9/val_batch0_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train9/confusion_matrix.png (deflated 26%)
#   adding: content/runs/detect/train9/train_batch0.jpg (deflated 2%)
#   adding: content/runs/detect/train9/F1_curve.png (deflated 8%)
# ...

# %% [markdown]
# ## **Splitting Dataset 70:30_10 NEW**

# %%
# Dataset 70:30_10

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="S4lowXmzTCfZjsbHzuzA")
project = rf.workspace("herbalplant").project("herbal-plant-w0fkh")
version = project.version(7)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Herbal-Plant-7 in yolov8:: 100%|██████████| 4898/4898 [00:00<00:00, 5951.14it/s]

# %%
# Train Dataset 70:30_10 -> NEW

# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data=/content/Herbal-Plant-7/data.yaml epochs=25 imgsz=640 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.2.33 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ## **Splitting Dataset 60:40_10 NEW**

# %%
# Dataset 60:40_10 - 54:36:10


# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="S4lowXmzTCfZjsbHzuzA")
project = rf.workspace("herbalplant").project("herbal-plant-w0fkh")
version = project.version(8)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Herbal-Plant-8 in yolov8:: 100%|██████████| 4392/4392 [00:00<00:00, 5827.50it/s]

# %%
# Train Dataset 60:40_10 -> NEW

# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data=/content/Herbal-Plant-8/data.yaml epochs=25 imgsz=640 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.2.33 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# NEW 80:20_10 - 72:18:10


# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="S4lowXmzTCfZjsbHzuzA")
project = rf.workspace("herbalplant").project("herbal-plant-w0fkh")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Herbal-Plant-6 in yolov8:: 100%|██████████| 5388/5388 [00:00<00:00, 5880.14it/s]

# %% [markdown]
# # **Training 500 epoch Used**

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="S4lowXmzTCfZjsbHzuzA")
project = rf.workspace("herbalplant").project("herbal-plant-w0fkh")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Herbal-Plant-6 in yolov8:: 100%|██████████| 5388/5388 [00:00<00:00, 5900.98it/s]

# %%
# Train Dataset 80:20_10 -> NEW

# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data=/content/Herbal-Plant-6/data.yaml epochs=500 imgsz=640 plots=True patience=False
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# Ubah 'folder_name' ke nama folder yang ingin Anda zip
folder_name = '/content/runs/detect/train10'

# Jalankan perintah zip di shell
# !zip -r {folder_name}.zip {folder_name}
# Out:
#   adding: content/runs/detect/train10/ (stored 0%)
#   adding: content/runs/detect/train10/train_batch2.jpg (deflated 1%)
#   adding: content/runs/detect/train10/val_batch1_pred.jpg (deflated 5%)
#   adding: content/runs/detect/train10/val_batch1_labels.jpg (deflated 5%)
#   adding: content/runs/detect/train10/events.out.tfevents.1718682254.6b627911d44d.19146.0 (deflated 73%)
#   adding: content/runs/detect/train10/R_curve.png (deflated 10%)
#   adding: content/runs/detect/train10/results.png (deflated 7%)
#   adding: content/runs/detect/train10/P_curve.png (deflated 11%)
#   adding: content/runs/detect/train10/PR_curve.png (deflated 14%)
#   adding: content/runs/detect/train10/val_batch0_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train10/confusion_matrix.png (deflated 27%)
#   adding: content/runs/detect/train10/train_batch76440.jpg (deflated 6%)
#   adding: content/runs/detect/train10/train_batch0.jpg (deflated 2%)
# ...

# %% [markdown]
# # **Training 500 Epoch**

# %%
# Train Dataset 80:20_10 -> NEW SGD optimizer

# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data=/content/Herbal-Plant-6/data.yaml epochs=500 imgsz=640 plots=True patience=False
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content/runs
# ...
# 100% 6.23M/6.23M [00:00<00:00, 109MB/s]
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# Ubah 'folder_name' ke nama folder yang ingin Anda zip
folder_name = '/content/runs/runs/detect/train'

# Jalankan perintah zip di shell
# !zip -r {folder_name}.zip {folder_name}
# Out:
#   adding: content/runs/runs/detect/train/ (stored 0%)
#   adding: content/runs/runs/detect/train/train_batch2.jpg (deflated 1%)
#   adding: content/runs/runs/detect/train/val_batch1_pred.jpg (deflated 5%)
#   adding: content/runs/runs/detect/train/val_batch1_labels.jpg (deflated 5%)
#   adding: content/runs/runs/detect/train/R_curve.png (deflated 10%)
#   adding: content/runs/runs/detect/train/results.png (deflated 8%)
#   adding: content/runs/runs/detect/train/P_curve.png (deflated 11%)
#   adding: content/runs/runs/detect/train/PR_curve.png (deflated 14%)
#   adding: content/runs/runs/detect/train/val_batch0_pred.jpg (deflated 6%)
#   adding: content/runs/runs/detect/train/confusion_matrix.png (deflated 27%)
#   adding: content/runs/runs/detect/train/train_batch76440.jpg (deflated 6%)
#   adding: content/runs/runs/detect/train/events.out.tfevents.1718690772.6b627911d44d.55338.0 (deflated 73%)
#   adding: content/runs/runs/detect/train/train_batch0.jpg (deflated 2%)
# ...

# %% [markdown]
# # **Training 50 Epoch**

# %%
# Train Dataset 80:20_10 -> NEW 50 epoch


# !yolo task=detect mode=train model=yolov8n.pt data=/content/Herbal-Plant-6/data.yaml epochs=50 imgsz=640 plots=True
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content/runs
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# Ubah 'folder_name' ke nama folder yang ingin Anda zip
folder_name = '/content/runs/runs/detect/train2'

# Jalankan perintah zip di shell
# !zip -r {folder_name}.zip {folder_name}
# Out:
#   adding: content/runs/runs/detect/train2/ (stored 0%)
#   adding: content/runs/runs/detect/train2/train_batch2.jpg (deflated 1%)
#   adding: content/runs/runs/detect/train2/val_batch1_pred.jpg (deflated 5%)
#   adding: content/runs/runs/detect/train2/val_batch1_labels.jpg (deflated 5%)
#   adding: content/runs/runs/detect/train2/events.out.tfevents.1718699171.6b627911d44d.90674.0 (deflated 77%)
#   adding: content/runs/runs/detect/train2/R_curve.png (deflated 10%)
#   adding: content/runs/runs/detect/train2/train_batch6241.jpg (deflated 6%)
#   adding: content/runs/runs/detect/train2/results.png (deflated 7%)
#   adding: content/runs/runs/detect/train2/P_curve.png (deflated 11%)
#   adding: content/runs/runs/detect/train2/train_batch6240.jpg (deflated 4%)
#   adding: content/runs/runs/detect/train2/PR_curve.png (deflated 16%)
#   adding: content/runs/runs/detect/train2/val_batch0_pred.jpg (deflated 6%)
#   adding: content/runs/runs/detect/train2/confusion_matrix.png (deflated 26%)
# ...

# %% [markdown]
# # **Training 100 Epoch**

# %%
# Train Dataset 80:20_10 -> NEW


# !yolo task=detect mode=train model=yolov8n.pt data=/content/Herbal-Plant-6/data.yaml epochs=100 imgsz=640 plots=True patience=False optimizer=AdamW lr0=0.001111 momentum=0.9
# Out:
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
# Ubah 'folder_name' ke nama folder yang ingin Anda zip
folder_name = '/content/runs/runs/detect/train3'

# Jalankan perintah zip di shell
# !zip -r {folder_name}.zip {folder_name}
# Out:
#   adding: content/runs/runs/detect/train3/ (stored 0%)
#   adding: content/runs/runs/detect/train3/train_batch2.jpg (deflated 1%)
#   adding: content/runs/runs/detect/train3/val_batch1_pred.jpg (deflated 5%)
#   adding: content/runs/runs/detect/train3/val_batch1_labels.jpg (deflated 5%)
#   adding: content/runs/runs/detect/train3/train_batch14040.jpg (deflated 6%)
#   adding: content/runs/runs/detect/train3/R_curve.png (deflated 10%)
#   adding: content/runs/runs/detect/train3/train_batch14041.jpg (deflated 4%)
#   adding: content/runs/runs/detect/train3/results.png (deflated 8%)
#   adding: content/runs/runs/detect/train3/P_curve.png (deflated 10%)
#   adding: content/runs/runs/detect/train3/events.out.tfevents.1718700208.6b627911d44d.95449.0 (deflated 75%)
#   adding: content/runs/runs/detect/train3/PR_curve.png (deflated 14%)
#   adding: content/runs/runs/detect/train3/val_batch0_pred.jpg (deflated 6%)
# ...
